# %%
# Simple Interest
P = float(input("Enter Principal: "))
R = float(input("Enter Rate (%): "))
T = float(input("Enter Time (years): "))

A = P * (1 + (R/100) * T)

print("Amount (Simple Interest) =", A)
# Out:
# Enter Principal:  200000
# Enter Rate (%):  30
# Enter Time (years):  4
# Amount (Simple Interest) = 440000.00000000006
