# %%
P = input("Principal")
R = input("Rate")
T = input("Time")
B = R / 100
A = P * (1 + (R / 100)*T))
print('Amount,', A)
# Out:
# Principal 20
# Rate 40
# Time 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 R = input("Rate")
#       3 T = input("Time")
# ----> 4 B = R / 100
#       5 A = P * (1 + (B*T))
#       6 print('Amount,', A)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
