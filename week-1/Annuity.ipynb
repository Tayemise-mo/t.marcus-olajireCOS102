# %%
# Annuity Plan
PMT = float(input("Enter payment per period: "))
R = float(input("Enter annual interest rate (decimal): "))
n = int(input("Enter number of payments per year: "))
t = float(input("Enter time (years): "))

A = PMT * ((1 + R/n) ** (n * t) - 1) / (R/n)

print("Future Value of Annuity =", A)
# Out:
# Enter payment per period:  200000
# Enter annual interest rate (decimal):  0.25
# Enter number of payments per year:  2
# Enter time (years):  5
# Future Value of Annuity = 3595713.6407494545
