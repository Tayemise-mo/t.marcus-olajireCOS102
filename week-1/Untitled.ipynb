# %%
P = float(input("Enter Principal (P): "))
R = (input("Enter Rate of Interest (R%): "))
T = (input("Enter Time in years (T): "))

A = P * (1 + (R / 100) * T)
print(f"The total Amount after {T} years is: {A:.2f}")
# Out:
# Enter Principal (P):  20000
# Enter Rate of Interest (R%):  40
# Enter Time in years (T):  3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       2 R = (input("Enter Rate of Interest (R%): "))
#       3 T = (input("Enter Time in years (T): "))
# ----> 5 A = P * (1 + (R / 100) * T)
#       6 print(f"The total Amount after {T} years is: {A:.2f}")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'
