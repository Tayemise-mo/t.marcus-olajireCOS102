# %% [markdown]
# ![diagram-export-3-9-2026-12_04_27-PM.png](attachment:d869acad-dbf5-4192-81e3-706d06f74391.png)

# %% [markdown]
# ![diagram-export-3-9-2026-12_11_41-PM.png](attachment:da730b90-bf0a-45b3-8cc1-0234a1bc6e92.png)

# %% [markdown]
# 10 INPUT Name 1
# 20 INPUT name 2
# 30 INPUT Age 1
# 40 INPUT Age 1
# 50 LET temp = Age 1
# 60 LET Age 1 = Age 2
# 70 LET Age 2 = temp
# 80 PRINT Age 1, Age 2
