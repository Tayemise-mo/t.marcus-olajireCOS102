# %%
str = input("Enter your state of origin:")

print ("Your state of origin is: ", str)
print ("The first character is: ", str[0])
print ("The characters starting from 3rd to 5th are: ", str[2:5])
print ("The string starting from 3rd character is: ", str[2:])
print ("State of origin two times", str * 2)
# Out:
# Enter your state of origin: Osun
# Your state of origin is:  Osun
# The first character is:  O
# The characters starting from 3rd to 5th are:  un
# The string starting from 3rd character is:  un
# State of origin two times OsunOsun

# %%
# Input from user
m = float(input("Enter mass in kilograms: "))

# Constant value for the speed of light in m/s
c = 299792458

# Calculating energy using Einstein's equation
energy = m * c ** 2

# Displaying the result
print(f"The energy equivalent to {m} kg of mass is {energy} joules.")
# Out:
# Enter mass in kilograms:  350
# The energy equivalent to 350.0 kg of mass is 3.1456431255788618e+19 joules.

# %%
list = [ 'Anaconda', 786, 2.23, 'Jupyter', 70.2 ]
shortlist = [321, 'Python']

print(list)            # ''' Prints complete list '''
print(list[0])         # Prints first element of the list
print(list[1:3])       # Prints elements starting from 2nd till 3rd
print(list[2:])        # ''' Prints elements starting from 3rd element'''
print(shortlist * 2)    # Prints list two times
print(list + shortlist) # prints concatenated lists
# Out:
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2]
# Anaconda
# [786, 2.23]
# [2.23, 'Jupyter', 70.2]
# [321, 'Python', 321, 'Python']
# ['Anaconda', 786, 2.23, 'Jupyter', 70.2, 321, 'Python']

# %%
tuple = ("Ekiti", 750, 'Oshogbo', 250, "Akure", 500)
s_tuple = ("Abeokuta", 300, "Ogbomoso")

#Prints the complete tuple
print (tuple)

#Prints last element of the tuple
print (tuple[-1])

#Prints elements of the tuple starting from 2nd till 3rd
print (tuple[2:4])

#Prints elements of the tuple starting from 3rd element
print (tuple[3:])

# Prints the contents of the tuple twice
print (s_tuple * 3)

# Print concatenated tuples
print (tuple + s_tuple)
# Out:
# ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500)
# 500
# ('Oshogbo', 250)
# (250, 'Akure', 500)
# ('Abeokuta', 300, 'Ogbomoso', 'Abeokuta', 300, 'Ogbomoso', 'Abeokuta', 300, 'Ogbomoso')
# ('Ekiti', 750, 'Oshogbo', 250, 'Akure', 500, 'Abeokuta', 300, 'Ogbomoso')

# %%
# Returns false as game_1 is not equal to game_2
game_1 = 2
game_2 = 4
print(bool(game_1 == game_2))
# Or
print(game_1 == game_2)

# Returns False as val is None
val = None
print(bool(val))

#Returns false as num is an empty sequence
num = ()
print(bool(num))

# Returns true as age is boolean
age = True
print(bool(age))
# Out:
# False
# False
# False
# False
# True

# %%
# Convert to int

grade = int(70)    # grade will be 70
gpa = int(4.9)     # gpa will be 4.9
cgpa = int("4")   # cgpa will be 4

print(f"Grade = {grade}")
print(f"GPA = {gpa}")
print(f"CGPA = {cgpa}")
# Out:
# Grade = 70
# GPA = 4
# CGPA = 4

# %%
# Convert to float

grade = float(97)   
gpa = float(5)     
cgpa = float("4.7")  

print(f"Grade = {grade}")
print(f"GPA = {gpa}")
print(f"CGPA = {cgpa}")
# Out:
# Grade = 97.0
# GPA = 5.0
# CGPA = 4.7

# %%
# EXAMPLE 1
# Print the given sequence of numbers using for loop 
count = [10,20,30,40,50]
for num in count:
    print(num)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
# EXAMPLE 2
# Print multiples of 10 for numbers in a given range
for num in range(5):
    if num > 0:
        print(num * 10)
# Out:
# 10
# 20
# 30
# 40

# %%
# EXAMPLE 3
# Print first 5 natural numbers using while loop
count = 1
while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# EXAMPLE 4
entry = 0
sum1 = 0
print("Enter numbers to find their sum, negative number ends the loop:")
while True:
    #int() typecasts string to integer
    entry = int(input())
    if (entry < 0):
        break
    sum1 += entry
print("Sum =", sum1)
# Out:
# Enter numbers to find their sum, negative number ends the loop:
#  4
#  5
#  -7
# Sum = 9

# %%
# EXAMPLE 5
num = 0
for num in range(6):
    num = num + 1
    if num == 3:
        continue
    print('Num has value ' + str(num))
print('End of loop')

# %%
# EXAMPLE 6
for var1 in range(3):
    print( "Iteration " + str(var1 + 1) + " of outer loop")
    for var2 in range(2): #nested loop
        print(var2 + 1)
    print("Out of inner loop")
print("Out of outer loop")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 # EXAMPLE 6
#       2 for var1 in range(3):
# ----> 3     print( "Iteration " + str(var1 + 1) + " of outer loop")
#       4     for var2 in range(2): #nested loop
#       5         print(var2 + 1)
#
# TypeError: 'str' object is not callable
